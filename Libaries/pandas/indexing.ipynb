# %%
import pandas as pd

# %%
df= pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/1_intro/nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#Find maximum temprature
df['Temperature'].max()
# Out:
# 50

# %%
#On which days did it rain
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
#what waas the average whethar speed
df.fillna(0, inplace = True) #to change none value to zero
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %% [markdown]
# TO MAKE DATAFRAME

# %%
wheather_data = {
    'Day' :['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'],
    'Temprature':[32,35,28,24,32,31],
    'Windspeed':[6, 7, 2, 7, 4, 2],
    'Event':['Rain', 'Sunny', 'Snow', 'Snow', 'Rain', 'Sunny']
}

# %%
df = pd.DataFrame(wheather_data)
df
# Out:
#         Day  Temprature  Windspeed  Event
# 0  1/1/2017          32          6   Rain
# 1  1/2/2017          35          7  Sunny
# 2  1/3/2017          28          2   Snow
# 3  1/4/2017          24          7   Snow
# 4  1/5/2017          32          4   Rain
# 5  1/6/2017          31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
rows, columns = df.shape
rows
# Out:
# 6

# %%
columns
# Out:
# 4

# %%
df.head(3)
# Out:
#         Day  Temprature  Windspeed  Event
# 0  1/1/2017          32          6   Rain
# 1  1/2/2017          35          7  Sunny
# 2  1/3/2017          28          2   Snow

# %%
df.tail()
# Out:
#         Day  Temprature  Windspeed  Event
# 1  1/2/2017          35          7  Sunny
# 2  1/3/2017          28          2   Snow
# 3  1/4/2017          24          7   Snow
# 4  1/5/2017          32          4   Rain
# 5  1/6/2017          31          2  Sunny

# %%
df[2:5]
# Out:
#         Day  Temprature  Windspeed Event
# 2  1/3/2017          28          2  Snow
# 3  1/4/2017          24          7  Snow
# 4  1/5/2017          32          4  Rain

# %%
df.columns
# Out:
# Index(['Day', 'Temprature', 'Windspeed', 'Event'], dtype='object')

# %%
df.Day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: Day, dtype: object

# %%
df['Event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: Event, dtype: object

# %%
type(df['Event'])
# Out:
# pandas.core.series.Series

# %%
df[['Event', 'Day']]
# Out:
#    Event       Day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %%
df[['Event', 'Day', 'Temprature']]
# Out:
#    Event       Day  Temprature
# 0   Rain  1/1/2017          32
# 1  Sunny  1/2/2017          35
# 2   Snow  1/3/2017          28
# 3   Snow  1/4/2017          24
# 4   Rain  1/5/2017          32
# 5  Sunny  1/6/2017          31

# %%
df['Temprature'].max()
# Out:
# 35

# %%
df['Temprature'].mean()
# Out:
# 30.333333333333332

# %%
df['Temprature'].std()
# Out:
# 3.8297084310253524

# %%
df.describe()
# Out:
#        Temprature  Windspeed
# count    6.000000   6.000000
# mean    30.333333   4.666667
# std      3.829708   2.338090
# min     24.000000   2.000000
# 25%     28.750000   2.500000
# 50%     31.500000   5.000000
# 75%     32.000000   6.750000
# max     35.000000   7.000000

# %%
df[df.Temprature >= 32]
# Out:
#         Day  Temprature  Windspeed  Event
# 0  1/1/2017          32          6   Rain
# 1  1/2/2017          35          7  Sunny
# 4  1/5/2017          32          4   Rain

# %%
df[df.Temprature == df.Temprature.max()]
# Out:
#         Day  Temprature  Windspeed  Event
# 1  1/2/2017          35          7  Sunny

# %%
df['Day'][df.Temprature == df['Temprature'].max()]
# Out:
# 1    1/2/2017
# Name: Day, dtype: object

# %%
df[['Day', 'Temprature']][df.Temprature == df['Temprature'].max()]
# Out:
#         Day  Temprature
# 1  1/2/2017          35

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
#Change the index to date as another dataset
df.set_index('Day')
# Out:
#           Temprature  Windspeed  Event
# Day
# 1/1/2017          32          6   Rain
# 1/2/2017          35          7  Sunny
# 1/3/2017          28          2   Snow
# 1/4/2017          24          7   Snow
# 1/5/2017          32          4   Rain
# 1/6/2017          31          2  Sunny

# %%
#Change the index to date as orginal dataset
df.set_index('Day', inplace=True)

# %%
df
# Out:
#           Temprature  Windspeed  Event
# Day
# 1/1/2017          32          6   Rain
# 1/2/2017          35          7  Sunny
# 1/3/2017          28          2   Snow
# 1/4/2017          24          7   Snow
# 1/5/2017          32          4   Rain
# 1/6/2017          31          2  Sunny

# %%
df.loc['1/3/2017']
# Out:
# Temprature      28
# Windspeed        2
# Event         Snow
# Name: 1/3/2017, dtype: object

# %%
#Change the date to index as orginal dataset
df.reset_index(inplace=True)

# %%
df
# Out:
#         Day  Temprature  Windspeed  Event
# 0  1/1/2017          32          6   Rain
# 1  1/2/2017          35          7  Sunny
# 2  1/3/2017          28          2   Snow
# 3  1/4/2017          24          7   Snow
# 4  1/5/2017          32          4   Rain
# 5  1/6/2017          31          2  Sunny

# %%
filter_df = df[df['Temprature'] > 30 ]
filter_df
# Out:
#         Day  Temprature  Windspeed  Event
# 0  1/1/2017          32          6   Rain
# 1  1/2/2017          35          7  Sunny
# 4  1/5/2017          32          4   Rain
# 5  1/6/2017          31          2  Sunny

# %%
sorted_df = df.sort_values(by='Windspeed', ascending=False)
sorted_df
# Out:
#         Day  Temprature  Windspeed  Event
# 1  1/2/2017          35          7  Sunny
# 3  1/4/2017          24          7   Snow
# 0  1/1/2017          32          6   Rain
# 4  1/5/2017          32          4   Rain
# 2  1/3/2017          28          2   Snow
# 5  1/6/2017          31          2  Sunny

# %%
def status_based_0n_temprature(Temprature):
    if Temprature >= 30:
        return 'HOT'
    else:
        return 'COLD'
df['Status'] = df['Temprature'].apply(status_based_0n_temprature)
df
# Out:
#         Day  Temprature  Windspeed  Event Status
# 0  1/1/2017          32          6   Rain    HOT
# 1  1/2/2017          35          7  Sunny    HOT
# 2  1/3/2017          28          2   Snow   COLD
# 3  1/4/2017          24          7   Snow   COLD
# 4  1/5/2017          32          4   Rain    HOT
# 5  1/6/2017          31          2  Sunny    HOT
