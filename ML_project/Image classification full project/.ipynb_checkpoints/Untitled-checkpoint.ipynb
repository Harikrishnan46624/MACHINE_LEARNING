# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [raw]
# (1) Preprocessing: Detect face and eyes
# When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.
#
# Now how do you detect face and eyes?

# %%
img = cv2.imread(r"E:\Programming\Machine Learning\ML_project\Image classification full project\Model\test_images\sharapova1.jpg")
img.shape
# Out:
# (555, 700, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (555, 700)

# %%
gray
# Out:
# array([[175, 175, 175, ..., 176, 175, 174],
#        [175, 175, 175, ..., 177, 175, 174],
#        [175, 175, 175, ..., 177, 176, 174],
#        ...,
#        [ 84,  87,  88, ..., 113, 113, 113],
#        [ 88,  89,  90, ..., 113, 113, 113],
#        [ 93,  91,  91, ..., 112, 112, 112]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier(r"E:\Programming\Machine Learning\ML_project\Image classification full project\Model\opencv\haarcascades\haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(r"E:\Programming\Machine Learning\ML_project\Image classification full project\Model\opencv\haarcascades\haarcascade_eye.xml")

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[352,  38, 233, 233]])
